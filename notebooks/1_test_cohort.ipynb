# %%
from sims_pars import bayes_net_from_script, sample
from scipy.integrate import solve_ivp
import numpy as np
import pandas as pd

from ppa.pars import *
from ppa.ebm.cohort import Model

# %%
with open('data/prior.txt', 'r') as f:
    prior = bayes_net_from_script(f.read())

cr = CasRepo.load('data/pars_india.json')

# %%
exo = sample(prior)
ps = cr.prepare_pars(exo=exo)
ps
# Out:
# {'p_txi': array([0.9725314 , 0.87448522, 0.62535755]),
#  'p_dx': array([0.65      , 0.49901223, 0.49901223]),
#  'p_dx0': array([0.65      , 0.49901223, 0.49901223]),
#  'p_dx1': array([0.65      , 0.49901223, 0.49901223]),
#  'p_ent': array([0.483     , 0.24733879, 0.26966121]),
#  'r_onset': 1.865593932883083,
#  'r_csi': 5.030926629248235,
#  'r_recsi': 5.205758528026443,
#  'mu_a': 0.3302430888105337,
#  'mu_s': 0.41234071294083513,
#  'mu_c': 0.41234071294083513,
#  'tx_alo': array([[1.       , 0.       ],
#         [0.0200878, 0.9799122],
#         [0.       , 1.       ]]),
#  'tx_dur': array([0.5       , 0.67896261]),
#  'r_txs': array([1.64888396, 1.01701686]),
#  'r_txd': array([0.08310736, 0.037134  ]),
#  'r_txl': array([0.26800868, 0.41868429]),
#  'ppv': array([0.75      , 0.49242791, 0.49242791]),
#  'inc': 0.002704832043322197,
#  'prev_ut': 0.0020096,
#  'prev_asc': (0.0012318, 0.00042218, 0.00035562),
#  'rr_die_asym': 0.47937093546012155,
#  'r_die_sym': 0.15768928344954708,
#  'r_sc': 0.25465142949128805,
#  'r_die_asym': 0.07559165931924565}

# %%
m = Model()
m.simulate(ps).tail()
# Out:
#     Time    N        S_Asym         S_Sym        S_ExCS       S_TxPub  \
# 27   2.7  1.0  2.666997e-03  1.530068e-03  4.068680e-03  1.967426e-02
# 28   2.8  1.0  2.145377e-03  1.229316e-03  3.311223e-03  1.682585e-02
# 29   2.9  1.0  1.721470e-03  9.874048e-04  2.691816e-03  1.436353e-02
# 30   3.0  1.0  1.380422e-03  7.927169e-04  2.185535e-03  1.223701e-02
# 31  20.0  1.0  1.274702e-19 -1.829239e-07  1.894394e-07 -5.884965e-09
#
#          S_TxPri  E_SelfCured  E_UtDeath  E_TxSucc  E_TxLTFU  E_TxDeath
# 27  2.344710e-02     0.188216   0.079262  0.527662  0.129305   0.024168
# 28  2.069176e-02     0.188405   0.079359  0.532914  0.130717   0.024402
# 29  1.823096e-02     0.188558   0.079439  0.537457  0.131948   0.024603
# 30  1.603712e-02     0.188683   0.079503  0.541385  0.133020   0.024777
# 31 -3.151833e-09     0.189198   0.079770  0.565313  0.139903   0.025816
